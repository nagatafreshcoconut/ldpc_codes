# %% [markdown]
# # Determine the [n, k, d] code configuration for a given polynomial A and B

# %% [markdown]
# #### Imports

# %%
import sys
import io
import numpy as np
import re
import time
from numpy.linalg import matrix_power as matrix_power
from numpy.linalg import matrix_rank as matrix_rank
from itertools import product

from mip import Model, xsum, minimize, BINARY
from bposd.css import css_code
from concurrent.futures import ThreadPoolExecutor

# %%
# Function to create the cyclic shift matrix S_l of size lxl
def get_cyclic_shift_matrix_S(l: int):
    S_l = np.roll(np.eye(l), 1, axis=1)
    return S_l

# Function to evaluate a polynomial at a matrix
def get_matrix_polynomial(poly, x, y):
    # Define a regular expression pattern to match 'x' or 'y' followed by numbers
    pattern = r'([xy])(\d*)'

    # Split the input string into individual terms
    terms = poly.split('+')

    # Initialize the result matrix as an identity matrix
    result_matrix = np.zeros_like(x)

    # Process each term separately
    for term in terms:
        # Find all matches in the term
        matches = re.findall(pattern, term)
        
        # Initialize the term result matrix as an identity matrix
        term_result_matrix = np.eye(x.shape[0])
        
        # Iterate through the matches and perform matrix multiplication with the corresponding exponents
        for match in matches:
            matrix_name = match[0]
            exponent = int(match[1]) if match[1] else 1
            
            if matrix_name == 'x':
                term_result_matrix = np.dot(term_result_matrix, matrix_power(x, exponent))
            elif matrix_name == 'y':
                term_result_matrix = np.dot(term_result_matrix, matrix_power(y, exponent))
        
        # Add the term result matrix to the overall result matrix
        result_matrix += term_result_matrix
    
    return result_matrix % 2

# %% [markdown]
# #### Choose Parameters

# %%
l = 8
m = 8

A_polynomial = 'x3 + y3 + y2 + y6'
B_polynomial = 'y3 + x3 + x2 + x6'

# %%
# Create the identity matrices I_ℓ and I_m
I_l = np.eye(l)
I_m = np.eye(m)

# Create the cyclic shift matrices S_ℓ and S_m
S_l = get_cyclic_shift_matrix_S(l)
S_m = get_cyclic_shift_matrix_S(m)

# Create matrices x and y based on the tensor product
x = np.kron(S_l, I_m)
y = np.kron(I_l, S_m)

A = get_matrix_polynomial(A_polynomial, x, y)
B = get_matrix_polynomial(B_polynomial, x, y)

# %% [markdown]
# ##### Sanity Check

# %%
print(A_polynomial)
# Out:
# x3 + y3 + y2 + y6

# %%
print(B_polynomial)
# Out:
# y3 + x3 + x2 + x6

# %%
def commutator(A, B):
    return A @ B - B @ A

# %%
if not np.any(commutator(A, B)):
    print('A and B commute.')
else:
    raise ValueError('A and B do NOT commute as they should. Please check the code how they get created.')
# Out:
# A and B commute.

# %% [markdown]
# #### Generate Check-Matrices $H^{x} = [A|B]$ and $H^{z} = [B^{T} | A^{T}]$.

# %% [markdown]
# Here, the vertical bar indicates stacking the matrices horizontally and $T$ means the matrix transposition. As a check, both Hx and Hz should have the dimension $(n/2)$ x $n$

# %%
def generate_check_matrices(A, B):
    """
    Generate check matrices Hx and Hz.

    Parameters:
        A (numpy.ndarray): The matrix A.
        B (numpy.ndarray): The matrix B.

    Returns:
        Hx (numpy.ndarray): The check matrix Hx.
        Hz (numpy.ndarray): The check matrix Hz.
    """
    # Ensure that A and B have compatible dimensions
    if A.shape[0] != B.shape[0]:
        raise ValueError("A and B must have the same number of rows")

    # Calculate dimensions
    n = A.shape[1] + B.shape[1]

    # Create the check matrix Hx by horizontally stacking A and B
    Hx = np.hstack((A, B))

    # Create the check matrix Hz by horizontally stacking the transpose of B and A
    Hz = np.hstack((B.T, A.T))

    assert Hx.shape == (n/2, n) and Hz.shape == (n/2, n), "Hx and Hz must be of dimension (n/2, n)."
    return Hx, Hz

# %%
Hx, Hz = generate_check_matrices(A, B)

# %%
def check_commute(Hx, Hz):
    if not np.any((Hx @ Hz.T) % 2):
        print('X and Z checks commute.')
    else:
        raise ValueError('X and Z checks do NOT commute as they should. Please check the code how they get created.')

# %%
check_commute(Hx, Hz)
# Out:
# X and Z checks commute.

# %% [markdown]
# #### Obtain the code parameters $n, k, d$ of the **LDPC** code

# %% [markdown]
# ##### Physical Data qubits $n$

# %%
n = 2*l*m
print('Number of PHYSICAL DATA qubits:', n)
# Out:
# Number of PHYSICAL DATA qubits: 128

# %% [markdown]
# ##### Logical qubits $k$

# %% [markdown]
# Two approaches to calculate the number of logical qubits $k$:
# - $k = n - \text{rank}(H^{x}) - \text{rank}(H^{z})$
# - $k = 2 \cdot \text{dim}(\text{ker}(A) ∩ \text{ker}(B))$
#
# Their equivalence is shown in Lemma 1 on page 10.

# %%
def binary_row_reduction(H):
    """
    Perform row reduction on a binary matrix H over the field F2.
    """
    # Copy of H to avoid modifying the original matrix
    R = H.copy()

    # Number of rows and columns
    rows, cols = R.shape

    # Row reduction
    row = 0
    for col in range(cols):
        if row >= rows:
            break

        # Find a row with a 1 in the current column
        for i in range(row, rows):
            if R[i, col] == 1:
                R[[row, i]] = R[[i, row]]  # Swap rows
                break
        else:
            continue

        # Eliminate 1s in the current column from other rows
        for i in range(rows):
            if i != row and R[i, col] == 1:
                R[i] = (R[i] + R[row]) % 2

        row += 1

    return R

def binary_matrix_rank(H):
    """
    Compute the rank of a binary matrix H over the field F2.
    """
    # Perform row reduction
    row_reduced_H = binary_row_reduction(H)

    # Count the number of non-zero rows
    rank = sum(np.any(row) for row in row_reduced_H)
    return rank

# %%
k = n - binary_matrix_rank(Hx) - binary_matrix_rank(Hz)
print('Number of LOGICAL qubits:', k)
# Out:
# Number of LOGICAL qubits: 16

# %% [markdown]
# #### Net encoding rate $r = \frac{k}{2n}$

# %%
def get_net_encoding_rate(k, n):
    return k / (2*n)

# %%
r = get_net_encoding_rate(k, n)
print('Net encoding rate:', r)
# Out:
# Net encoding rate: 0.0625

# %% [markdown]
# #### Using the MIP package

# %%
# computes the minimum Hamming weight of a binary vector x such that
# stab @ x = 0 mod 2
# logicOp @ x = 1 mod 2
# here stab is a binary matrix and logicOp is a binary vector
def distance_test(stab,logicOp):
  # number of qubits
  n = stab.shape[1]
  # number of stabilizers
  m = stab.shape[0]

  # maximum stabilizer weight
  wstab = np.max([np.sum(stab[i,:]) for i in range(m)])
  # weight of the logical operator
  wlog = np.count_nonzero(logicOp)
  # how many slack variables are needed to express orthogonality constraints modulo two
  num_anc_stab = int(np.ceil(np.log2(wstab)))
  num_anc_logical = int(np.ceil(np.log2(wlog)))
  # total number of variables
  num_var = n + m*num_anc_stab + num_anc_logical

  model = Model()
  model.verbose = 0
  x = [model.add_var(var_type=BINARY) for i in range(num_var)]
  model.objective = minimize(xsum(x[i] for i in range(n)))

  # orthogonality to rows of stab constraints
  for row in range(m):
    weight = [0]*num_var
    supp = np.nonzero(stab[row,:])[0]
    for q in supp:
      weight[q] = 1
    cnt = 1
    for q in range(num_anc_stab):
      weight[n + row*num_anc_stab +q] = -(1<<cnt)
      cnt+=1
    model+= xsum(weight[i] * x[i] for i in range(num_var)) == 0

  # odd overlap with logicOp constraint
  supp = np.nonzero(logicOp)[0]
  weight = [0]*num_var
  for q in supp:
    weight[q] = 1
  cnt = 1
  for q in range(num_anc_logical):
      weight[n + m*num_anc_stab +q] = -(1<<cnt)
      cnt+=1
  model+= xsum(weight[i] * x[i] for i in range(num_var)) == 1

  model.optimize()

  opt_val = sum([x[i].x for i in range(n)])

  return int(opt_val)


def distance_test_parallel(stab, logicOp):
    n = stab.shape[1]  # number of qubits
    m = stab.shape[0]  # number of stabilizers

    # Parallel computation of wstab
    with ThreadPoolExecutor() as executor:
        wstab_list = list(executor.map(np.sum, stab))
    wstab = np.max(wstab_list)

    wlog = np.count_nonzero(logicOp)
    num_anc_stab = int(np.ceil(np.log2(wstab)))
    num_anc_logical = int(np.ceil(np.log2(wlog)))
    num_var = n + m * num_anc_stab + num_anc_logical

    model = Model()
    model.verbose = 0
    x = [model.add_var(var_type=BINARY) for i in range(num_var)]
    model.objective = minimize(xsum(x[i] for i in range(n)))

    # Function to prepare and add a constraint for a row of stab
    def add_stab_constraint(row):
        weight = [0] * num_var
        supp = np.nonzero(stab[row, :])[0]
        for q in supp:
            weight[q] = 1
        cnt = 1
        for q in range(num_anc_stab):
            weight[n + row * num_anc_stab + q] = -(1 << cnt)
            cnt += 1
        return xsum(weight[i] * x[i] for i in range(num_var)) == 0

    # Parallel addition of orthogonality constraints
    with ThreadPoolExecutor() as executor:
        constraints = list(executor.map(add_stab_constraint, range(m)))
    for constraint in constraints:
        model += constraint

    # Adding odd overlap with logicOp constraint (not parallelized)
    supp = np.nonzero(logicOp)[0]
    weight = [0] * num_var
    for q in supp:
        weight[q] = 1
    cnt = 1
    for q in range(num_anc_logical):
        weight[n + m * num_anc_stab + q] = -(1 << cnt)
        cnt += 1
    model += xsum(weight[i] * x[i] for i in range(num_var)) == 1

    model.optimize()
    opt_val = sum(x[i].x for i in range(n))

    return int(opt_val)

# %%
# Code parameters
ell, m = 6, 6
a1, a2, a3, a4 = 4, 4, 2, 4
b1, b2, b3, b4 = 4, 4, 2, 4

n = 2*ell*m
n2 = ell*m

# define cyclic shift matrices
I_ell = np.identity(ell, dtype=int)
I_m = np.identity(m, dtype=int)
I = np.identity(ell*m, dtype=int)
x = {}
y = {}
for i in range(ell):
	x[i] = np.kron(np.roll(I_ell, i, axis=1), I_m)
for i in range(m):
	y[i] = np.kron(I_ell, np.roll(I_m, i, axis=1))

# define check matrices
A = (x[a1] + y[a2] + y[a3] + y[a4]) % 2
B = (y[b1] + x[b2] + x[b3] + x[b4]) % 2

AT = np.transpose(A)
BT = np.transpose(B)
hx = np.hstack((A, B))
hz = np.hstack((BT, AT))

qcode=css_code(hx,hz)
print('Testing CSS code...')
qcode.test()
print('Done')

lz = qcode.lz
lx = qcode.lx
k = lz.shape[0]

# %%
n_phys_qubits = qcode.N
n_log_qubits = qcode.K

print('Number of PHYSICAL DATA qubits:', n_phys_qubits)
print('Number of LOGICAL qubits:', n_log_qubits)

print('Net Encoding Rate:', get_net_encoding_rate(n_log_qubits, n_phys_qubits))

# %% [markdown]
# ## Full Parameter Search

# %%
import itertools

# %%
def parameter_search(max_l: int = 10, max_m: int = 10, num_a_b_terms: int = 4):
    good_params = []
    
    # Code parameters
    for ell in range(4, max_l + 1):
        for m in range(4, max_m + 1):

            # Iterate over all combinations of a and b terms within the bounds
            for a_terms in itertools.combinations_with_replacement(range(1, ell), num_a_b_terms):
                for b_terms in itertools.combinations_with_replacement(range(1, m), num_a_b_terms):

                    # print(a_terms)
                    # print(b_terms)    

                    # a1, a2, a3, a4 = 2, 2, 1, 3
                    # b1, b2, b3, b4 = 2, 2, 1, 3

                    n = 2*ell*m
                    n2 = ell*m

                    # define cyclic shift matrices
                    I_ell = np.identity(ell, dtype=int)
                    I_m = np.identity(m, dtype=int)
                    I = np.identity(ell*m, dtype=int)
                    x = {}
                    y = {}
                    for i in range(ell):
                        x[i] = np.kron(np.roll(I_ell, i, axis=1), I_m)
                    for i in range(m):
                        y[i] = np.kron(I_ell, np.roll(I_m, i, axis=1))

                    # define check matrices
                    # A = (x[a1] + y[a2] + y[a3] + y[a4]) % 2
                    # B = (y[b1] + x[b2] + x[b3] + x[b4]) % 2
                    
                    # define check matrices using the a and b terms
                    A = sum(x[a_terms[i]] if i < len(a_terms) else y[a_terms[i]] for i in range(len(a_terms))) % 2
                    B = sum(y[b_terms[i]] if i < len(b_terms) else x[b_terms[i]] for i in range(len(b_terms))) % 2
                    AT = np.transpose(A)
                    BT = np.transpose(B)
                    hx = np.hstack((A, B))
                    hz = np.hstack((BT, AT))

                    qcode=css_code(hx,hz)
                    # print(qcode.test())
                    
                    r = get_net_encoding_rate(qcode.K, qcode.N)
                    if r > 1/20 and qcode.test():
                        code_config = {
                            'l': ell,
                            'm': m,
                            'a_coeffs': a_terms,
                            'b_coeffs': b_terms,
                            'n_phys_qubits': qcode.N,
                            'n_log_qubits': qcode.K,
                            'encoding_rate': r,
                        }
                        good_params.append(code_config)

    return good_params

# %%
good_params = parameter_search(max_l=10, max_m=10, num_a_b_terms=2)
# Out:
# <Unnamed CSS code>, (0,0)-[[32,32,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[32,32,nan]]
# <Unnamed CSS code>, (2,2)-[[32,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,8,nan]]
# <Unnamed CSS code>, (2,2)-[[32,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,16,nan]]
# <Unnamed CSS code>, (0,0)-[[32,32,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[32,32,nan]]
# <Unnamed CSS code>, (2,2)-[[32,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,8,nan]]
# <Unnamed CSS code>, (0,0)-[[32,32,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[32,32,nan]]
# <Unnamed CSS code>, (2,2)-[[32,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,8,nan]]
# <Unnamed CSS code>, (2,4)-[[32,4,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[32,4,nan]]
# <Unnamed CSS code>, (2,2)-[[32,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,8,nan]]
# <Unnamed CSS code>, (2,2)-[[32,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,8,nan]]
# <Unnamed CSS code>, (2,2)-[[32,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,16,nan]]
# <Unnamed CSS code>, (2,4)-[[32,4,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[32,4,nan]]
# <Unnamed CSS code>, (2,4)-[[32,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[32,8,nan]]
# <Unnamed CSS code>, (2,2)-[[32,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,16,nan]]
# <Unnamed CSS code>, (2,4)-[[32,4,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[32,4,nan]]
# <Unnamed CSS code>, (2,2)-[[32,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,16,nan]]
# <Unnamed CSS code>, (0,0)-[[32,32,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[32,32,nan]]
# <Unnamed CSS code>, (2,2)-[[32,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,8,nan]]
# <Unnamed CSS code>, (2,2)-[[32,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,16,nan]]
# <Unnamed CSS code>, (0,0)-[[32,32,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[32,32,nan]]
# <Unnamed CSS code>, (2,2)-[[32,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,8,nan]]
# <Unnamed CSS code>, (0,0)-[[32,32,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[32,32,nan]]
# <Unnamed CSS code>, (2,2)-[[32,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,8,nan]]
# <Unnamed CSS code>, (2,4)-[[32,4,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[32,4,nan]]
# <Unnamed CSS code>, (2,2)-[[32,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,8,nan]]
# <Unnamed CSS code>, (2,2)-[[32,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,8,nan]]
# <Unnamed CSS code>, (0,0)-[[32,32,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[32,32,nan]]
# <Unnamed CSS code>, (2,2)-[[32,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,8,nan]]
# <Unnamed CSS code>, (2,2)-[[32,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,16,nan]]
# <Unnamed CSS code>, (0,0)-[[32,32,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[32,32,nan]]
# <Unnamed CSS code>, (2,2)-[[32,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[32,8,nan]]
# <Unnamed CSS code>, (0,0)-[[32,32,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[32,32,nan]]
# <Unnamed CSS code>, (0,0)-[[40,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[40,40,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (0,0)-[[40,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[40,40,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (0,0)-[[40,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[40,40,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (0,0)-[[40,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[40,40,nan]]
# <Unnamed CSS code>, (2,2)-[[40,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,10,nan]]
# <Unnamed CSS code>, (2,2)-[[40,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,10,nan]]
# <Unnamed CSS code>, (2,2)-[[40,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,10,nan]]
# <Unnamed CSS code>, (2,2)-[[40,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,10,nan]]
# <Unnamed CSS code>, (2,2)-[[40,20,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,20,nan]]
# <Unnamed CSS code>, (2,2)-[[40,20,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,20,nan]]
# <Unnamed CSS code>, (2,2)-[[40,20,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,20,nan]]
# <Unnamed CSS code>, (2,2)-[[40,20,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,20,nan]]
# <Unnamed CSS code>, (0,0)-[[40,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[40,40,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (0,0)-[[40,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[40,40,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (0,0)-[[40,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[40,40,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (0,0)-[[40,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[40,40,nan]]
# <Unnamed CSS code>, (2,2)-[[40,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,10,nan]]
# <Unnamed CSS code>, (2,2)-[[40,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,10,nan]]
# <Unnamed CSS code>, (2,2)-[[40,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,10,nan]]
# <Unnamed CSS code>, (2,2)-[[40,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,10,nan]]
# <Unnamed CSS code>, (0,0)-[[40,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[40,40,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (0,0)-[[40,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[40,40,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (0,0)-[[40,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[40,40,nan]]
# <Unnamed CSS code>, (2,2)-[[40,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[40,8,nan]]
# <Unnamed CSS code>, (0,0)-[[40,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[40,40,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (2,2)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,8,nan]]
# <Unnamed CSS code>, (2,2)-[[48,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,16,nan]]
# <Unnamed CSS code>, (2,2)-[[48,24,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,24,nan]]
# <Unnamed CSS code>, (2,2)-[[48,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,16,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (2,2)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,8,nan]]
# <Unnamed CSS code>, (2,2)-[[48,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,16,nan]]
# <Unnamed CSS code>, (2,2)-[[48,24,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,24,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (2,2)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,8,nan]]
# <Unnamed CSS code>, (2,2)-[[48,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,16,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (2,2)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,8,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (2,2)-[[48,12,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,12,nan]]
# <Unnamed CSS code>, (2,4)-[[48,6,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[48,6,nan]]
# <Unnamed CSS code>, (2,2)-[[48,12,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,12,nan]]
# <Unnamed CSS code>, (2,4)-[[48,6,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[48,6,nan]]
# <Unnamed CSS code>, (2,2)-[[48,12,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,12,nan]]
# <Unnamed CSS code>, (2,2)-[[48,12,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,12,nan]]
# <Unnamed CSS code>, (2,2)-[[48,12,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,12,nan]]
# <Unnamed CSS code>, (2,2)-[[48,24,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,24,nan]]
# <Unnamed CSS code>, (2,4)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[48,8,nan]]
# <Unnamed CSS code>, (2,4)-[[48,12,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[48,12,nan]]
# <Unnamed CSS code>, (2,4)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[48,8,nan]]
# <Unnamed CSS code>, (2,2)-[[48,24,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,24,nan]]
# <Unnamed CSS code>, (2,4)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[48,8,nan]]
# <Unnamed CSS code>, (2,4)-[[48,12,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[48,12,nan]]
# <Unnamed CSS code>, (2,2)-[[48,24,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,24,nan]]
# <Unnamed CSS code>, (2,4)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[48,8,nan]]
# <Unnamed CSS code>, (2,2)-[[48,24,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,24,nan]]
# <Unnamed CSS code>, (2,2)-[[48,24,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,24,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (2,2)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,8,nan]]
# <Unnamed CSS code>, (2,2)-[[48,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,16,nan]]
# <Unnamed CSS code>, (2,2)-[[48,24,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,24,nan]]
# <Unnamed CSS code>, (2,2)-[[48,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,16,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (2,2)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,8,nan]]
# <Unnamed CSS code>, (2,2)-[[48,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,16,nan]]
# <Unnamed CSS code>, (2,2)-[[48,24,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,24,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (2,2)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,8,nan]]
# <Unnamed CSS code>, (2,2)-[[48,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,16,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (2,2)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,8,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (2,2)-[[48,12,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,12,nan]]
# <Unnamed CSS code>, (2,4)-[[48,6,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[48,6,nan]]
# <Unnamed CSS code>, (2,2)-[[48,12,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,12,nan]]
# <Unnamed CSS code>, (2,4)-[[48,6,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,4)-[[48,6,nan]]
# <Unnamed CSS code>, (2,2)-[[48,12,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,12,nan]]
# <Unnamed CSS code>, (2,2)-[[48,12,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,12,nan]]
# <Unnamed CSS code>, (2,2)-[[48,12,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,12,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (2,2)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,8,nan]]
# <Unnamed CSS code>, (2,2)-[[48,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,16,nan]]
# <Unnamed CSS code>, (2,2)-[[48,24,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,24,nan]]
# <Unnamed CSS code>, (2,2)-[[48,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,16,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (2,2)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,8,nan]]
# <Unnamed CSS code>, (2,2)-[[48,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,16,nan]]
# <Unnamed CSS code>, (2,2)-[[48,24,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,24,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (2,2)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,8,nan]]
# <Unnamed CSS code>, (2,2)-[[48,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,16,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (2,2)-[[48,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[48,8,nan]]
# <Unnamed CSS code>, (0,0)-[[48,48,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[48,48,nan]]
# <Unnamed CSS code>, (0,0)-[[56,56,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[56,56,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (0,0)-[[56,56,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[56,56,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (0,0)-[[56,56,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[56,56,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (0,0)-[[56,56,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[56,56,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (0,0)-[[56,56,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[56,56,nan]]
# <Unnamed CSS code>, (2,2)-[[56,8,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,8,nan]]
# <Unnamed CSS code>, (0,0)-[[56,56,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[56,56,nan]]
# <Unnamed CSS code>, (2,2)-[[56,14,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,14,nan]]
# <Unnamed CSS code>, (2,2)-[[56,14,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,14,nan]]
# <Unnamed CSS code>, (2,2)-[[56,14,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,14,nan]]
# <Unnamed CSS code>, (2,2)-[[56,14,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,14,nan]]
# <Unnamed CSS code>, (2,2)-[[56,14,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,14,nan]]
# <Unnamed CSS code>, (2,2)-[[56,14,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,14,nan]]
# <Unnamed CSS code>, (2,2)-[[56,28,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,28,nan]]
# <Unnamed CSS code>, (2,2)-[[56,28,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,28,nan]]
# <Unnamed CSS code>, (2,2)-[[56,28,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,28,nan]]
# <Unnamed CSS code>, (2,2)-[[56,28,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,28,nan]]
# <Unnamed CSS code>, (2,2)-[[56,28,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[56,28,nan]]
# <Unnamed CSS code>, (2,2)-[[56,28,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
# ...
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,10,nan]]
# <Unnamed CSS code>, (0,0)-[[80,80,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[80,80,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# <Unnamed CSS code>, (0,0)-[[80,80,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[80,80,nan]]
# <Unnamed CSS code>, (2,2)-[[80,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,10,nan]]
# <Unnamed CSS code>, (2,2)-[[80,20,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,20,nan]]
# <Unnamed CSS code>, (2,2)-[[80,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,10,nan]]
# <Unnamed CSS code>, (2,2)-[[80,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,40,nan]]
# <Unnamed CSS code>, (2,2)-[[80,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,10,nan]]
# <Unnamed CSS code>, (2,2)-[[80,20,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,20,nan]]
# <Unnamed CSS code>, (0,0)-[[80,80,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[80,80,nan]]
# <Unnamed CSS code>, (2,2)-[[80,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,10,nan]]
# <Unnamed CSS code>, (2,2)-[[80,20,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,20,nan]]
# <Unnamed CSS code>, (2,2)-[[80,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,10,nan]]
# <Unnamed CSS code>, (2,2)-[[80,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,40,nan]]
# <Unnamed CSS code>, (2,2)-[[80,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,10,nan]]
# <Unnamed CSS code>, (0,0)-[[80,80,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[80,80,nan]]
# <Unnamed CSS code>, (2,2)-[[80,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,10,nan]]
# <Unnamed CSS code>, (2,2)-[[80,20,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,20,nan]]
# <Unnamed CSS code>, (2,2)-[[80,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,10,nan]]
# <Unnamed CSS code>, (2,2)-[[80,40,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,40,nan]]
# <Unnamed CSS code>, (0,0)-[[80,80,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[80,80,nan]]
# <Unnamed CSS code>, (2,2)-[[80,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,10,nan]]
# <Unnamed CSS code>, (2,2)-[[80,20,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,20,nan]]
# <Unnamed CSS code>, (2,2)-[[80,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,10,nan]]
# <Unnamed CSS code>, (0,0)-[[80,80,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[80,80,nan]]
# <Unnamed CSS code>, (2,2)-[[80,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,10,nan]]
# <Unnamed CSS code>, (2,2)-[[80,20,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,20,nan]]
# <Unnamed CSS code>, (0,0)-[[80,80,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[80,80,nan]]
# <Unnamed CSS code>, (2,2)-[[80,10,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,10,nan]]
# <Unnamed CSS code>, (0,0)-[[80,80,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (0,0)-[[80,80,nan]]
# <Unnamed CSS code>, (2,2)-[[80,16,nan]]
#  -Block dimensions: Pass
#  -PCMs commute hz@hx.T==0: Pass
#  -PCMs commute hx@hz.T==0: Pass
#  -lx \in ker{hz} AND lz \in ker{hx}: Pass
#  -lx and lz anticommute: Pass
#  -<Unnamed CSS code> is a valid CSS code w/ params (2,2)-[[80,16,nan]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 good_params = parameter_search(max_l=10, max_m=10, num_a_b_terms=2)
#
# Cell In[22], line 44, in parameter_search(max_l, max_m, num_a_b_terms)
#      41 hx = np.hstack((A, B))
#      42 hz = np.hstack((BT, AT))
# ---> 44 qcode=css_code(hx,hz)
#      45 # print(qcode.test())
#      47 r = get_net_encoding_rate(qcode.K, qcode.N)
#
# File ~/Library/Python/3.9/lib/python/site-packages/bposd/css.py:31, in css_code.__init__(self, hx, hz, code_distance, name)
#      28     raise Exception("Error: hx and hz matrices must have equal numbers of columns!")
#      30 if nx!=0:
# ---> 31     self.compute_dimension()
#      32     self.compute_ldpc_params()
#      33     self.compute_logicals()
#
# File ~/Library/Python/3.9/lib/python/site-packages/bposd/css.py:50, in css_code.compute_dimension(self)
#      47 self.N=self.hx.shape[1]
#      48 assert self.N == self.hz.shape[1], "Code block length (N) inconsistent!"
# ---> 50 self.K=self.N-mod2.rank(self.hx)-mod2.rank(self.hz)
#      51 return self.K
#
# File ~/Library/Python/3.9/lib/python/site-packages/ldpc/mod2.py:201, in rank(matrix)
#     174 def rank(matrix):
#     175     """
#     176     Returns the rank of a binary matrix
#     177
#    (...)
#     199
#     200     """
# --> 201     return row_echelon(matrix)[1]
#
# File ~/Library/Python/3.9/lib/python/site-packages/ldpc/mod2.py:155, in row_echelon(matrix, full)
#     151 for j in elimination_range:
#     153     if the_matrix[j, col] != 0 and pivot_row != j:    ### Do we need second condition?
# --> 155         the_matrix[j] = (the_matrix[j] + the_matrix[pivot_row]) % 2
#     157         # Update transformation matrix to reflect this op
#     158         transform_matrix[j] = (transform_matrix[j] + transform_matrix[pivot_row]) % 2
#
# KeyboardInterrupt:

# %%
def build_code(ell, m):
    good_configs = []
    
    # Define cyclic shift matrices
    I_ell = np.identity(ell, dtype=int)
    I_m = np.identity(m, dtype=int)
    x, y = {}, {}
    for i in range(ell):
        x[i] = np.kron(np.roll(I_ell, i, axis=1), I_m)
    for i in range(m):
        y[i] = np.kron(I_ell, np.roll(I_m, i, axis=1))

    # Parameter bounds
    max_param = max(ell, m)

    # Iterate through all possible combinations of a and b within the bounds
    for a_combination in itertools.product(range(max_param), repeat=4):
        for b_combination in itertools.product(range(max_param), repeat=4):
            # Construct check matrices A and B
            A = sum(x.get(a, np.zeros((ell*m, ell*m), dtype=int)) for a in a_combination) % 2
            B = sum(y.get(b, np.zeros((ell*m, ell*m), dtype=int)) for b in b_combination) % 2

            AT = np.transpose(A)
            BT = np.transpose(B)
            hx = np.hstack((A, B))
            hz = np.hstack((BT, AT))

            qcode = css_code(hx, hz)
            if qcode.test():
                r = get_net_encoding_rate(qcode.K, qcode.N)
                if r > 1/15:  # Your specific criteria for good configurations
                    code_config = {
                        'ell': ell,
                        'm': m,
                        'a_coeffs': a_combination,
                        'b_coeffs': b_combination,
                        'n_phys_qubits': qcode.N,
                        'n_log_qubits': qcode.K,
                        'encoding_rate': r,
                    }
                    good_configs.append(code_config)

    return good_configs

# %%
def build_code(max_ell, max_m):
    good_configs = []

    # Iterate through the range of values for ell and m up to their maximum values
    for ell in range(4, max_ell + 1):
        for m in range(4, max_m + 1):
            # Define cyclic shift matrices based on the current ell and m
            I_ell = np.identity(ell, dtype=int)
            I_m = np.identity(m, dtype=int)
            x, y = {}, {}
            for i in range(ell):
                x[i] = np.kron(np.roll(I_ell, i, axis=1), I_m)
            for i in range(m):
                y[i] = np.kron(I_ell, np.roll(I_m, i, axis=1))

            # Directly use the predefined a and b values or a specific combination for A and B
            a1, a2, a3 = 3, 1, 2  # Predefined or derived values for a
            b1, b2, b3 = 3, 1, 2  # Predefined or derived values for b

            # Construct check matrices A and B
            A = (x[a1] + y[a2] + y[a3]) % 2
            B = (y[b1] + x[b2] + x[b3]) % 2

            # Transpose matrices A and B
            AT = np.transpose(A)
            BT = np.transpose(B)

            # Construct matrices hx and hz
            hx = np.hstack((A, B))
            hz = np.hstack((BT, AT))

            # Construct the CSS code and test it
            qcode = css_code(hx, hz)
            if qcode.test():
                r = get_net_encoding_rate(qcode.K, qcode.N)
                if r > 1/15:  # Your specific criteria for good configurations
                    code_config = {
                        'ell': ell,
                        'm': m,
                        'n_phys_qubits': qcode.N,
                        'n_log_qubits': qcode.K,
                        'encoding_rate': r,
                    }
                    good_configs.append(code_config)

    return good_configs

# %%
def search_codes(max_ell, max_m, num_summands_a, num_summands_b):
    good_configs = []

    for ell in range(6, max_ell + 1):
        for m in range(6, max_m + 1):
            I_ell = np.identity(ell, dtype=int)
            I_m = np.identity(m, dtype=int)
            x, y = {}, {}
            for i in range(ell):
                x[i] = np.kron(np.roll(I_ell, i, axis=1), I_m)
            for j in range(m):
                y[j] = np.kron(I_ell, np.roll(I_m, j, axis=1))

            # Iterate over all possible fixed indices for x in A and y in B
            for fixed_x_index_a in range(1, 4):
                for fixed_y_index_b in range(1, 4):
                    # Exclude the fixed indices from the possible combinations
                    x_indices = [i for i in range(ell) if i != fixed_x_index_a]
                    y_indices = [i for i in range(m) if i != fixed_y_index_b]

                    # Iterate over combinations for the non-fixed terms
                    for combo_a in itertools.combinations(y_indices, num_summands_a - 1):  # -1 for the fixed x term
                        for combo_b in itertools.combinations(x_indices, num_summands_b - 1):  # -1 for the fixed y term
                            # Construct A and B with the fixed term and current combinations
                            A = x[fixed_x_index_a]
                            for idx in combo_a:
                                A += y[idx]
                            A %= 2

                            B = y[fixed_y_index_b]
                            for idx in combo_b:
                                B += x[idx]
                            B %= 2

                            # Construct polynomial sum strings for A and B
                            A_poly_sum = f"x[{fixed_x_index_a}]" + " + " + " + ".join(f"y[{idx}]" for idx in combo_a)
                            B_poly_sum = f"y[{fixed_y_index_b}]" + " + " + " + ".join(f"x[{idx}]" for idx in combo_b)

                            # Transpose matrices A and B
                            AT = np.transpose(A)
                            BT = np.transpose(B)

                            # Construct matrices hx and hz
                            hx = np.hstack((A, B))
                            hz = np.hstack((BT, AT))

                            # Construct the CSS code and test it
                            qcode = css_code(hx, hz)  # Assuming css_code is defined elsewhere
                            if qcode.test():  # Assuming the test method is defined for qcode
                                r = get_net_encoding_rate(qcode.K, qcode.N)  # Assuming this function is defined
                                if r > 1/20:  # Your specific criteria for good configurations
                                    code_config = {
                                        'ell': ell,
                                        'm': m,
                                        'n_phys_qubits': qcode.N,
                                        'n_log_qubits': qcode.K,
                                        'encoding_rate': r,
                                        'A_poly_sum': A_poly_sum,
                                        'B_poly_sum': B_poly_sum
                                    }
                                    good_configs.append(code_config)

    return good_configs

# %%
### Surpress the print statements of the qcode.test() function
# Save the current stdout so we can restore it later
original_stdout = sys.stdout
# Redirect stdout to a dummy StringIO object
sys.stdout = io.StringIO()

# Example usage
good_configs = search_codes(max_ell=6, max_m=6, num_summands_a=3, num_summands_b=3)
len(good_configs)
# Out:
# 23

# %%
good_configs
# Out:
# [{'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[1] + y[0] + y[1]',
#   'B_poly_sum': 'y[2] + x[0] + x[2]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[1] + y[0] + y[4]',
#   'B_poly_sum': 'y[2] + x[0] + x[2]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[1] + y[1] + y[3]',
#   'B_poly_sum': 'y[2] + x[0] + x[2]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[1] + y[3] + y[4]',
#   'B_poly_sum': 'y[2] + x[0] + x[2]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[1] + y[0] + y[1]',
#   'B_poly_sum': 'y[3] + x[2] + x[3]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[1] + y[0] + y[1]',
#   'B_poly_sum': 'y[3] + x[3] + x[5]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[1] + y[0] + y[5]',
#   'B_poly_sum': 'y[3] + x[2] + x[3]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[1] + y[0] + y[5]',
#   'B_poly_sum': 'y[3] + x[3] + x[5]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[2] + y[0] + y[2]',
#   'B_poly_sum': 'y[1] + x[0] + x[1]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[2] + y[0] + y[4]',
#   'B_poly_sum': 'y[2] + x[0] + x[1]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[2] + y[0] + y[2]',
#   'B_poly_sum': 'y[3] + x[1] + x[3]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[2] + y[0] + y[2]',
#   'B_poly_sum': 'y[3] + x[3] + x[5]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[2] + y[0] + y[4]',
#   'B_poly_sum': 'y[3] + x[1] + x[3]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[2] + y[0] + y[4]',
#   'B_poly_sum': 'y[3] + x[3] + x[5]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[3] + y[4] + y[5]',
#   'B_poly_sum': 'y[1] + x[0] + x[1]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 12,
#   'encoding_rate': 0.08333333333333333,
#   'A_poly_sum': 'x[3] + y[1] + y[2]',
#   'B_poly_sum': 'y[3] + x[1] + x[2]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 12,
#   'encoding_rate': 0.08333333333333333,
#   'A_poly_sum': 'x[3] + y[1] + y[2]',
#   'B_poly_sum': 'y[3] + x[2] + x[5]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[3] + y[1] + y[5]',
#   'B_poly_sum': 'y[3] + x[1] + x[2]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[3] + y[1] + y[5]',
#   'B_poly_sum': 'y[3] + x[2] + x[5]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[3] + y[2] + y[4]',
#   'B_poly_sum': 'y[3] + x[1] + x[2]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 8,
#   'encoding_rate': 0.05555555555555555,
#   'A_poly_sum': 'x[3] + y[2] + y[4]',
#   'B_poly_sum': 'y[3] + x[2] + x[5]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 12,
#   'encoding_rate': 0.08333333333333333,
#   'A_poly_sum': 'x[3] + y[4] + y[5]',
#   'B_poly_sum': 'y[3] + x[1] + x[2]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 12,
#   'encoding_rate': 0.08333333333333333,
#   'A_poly_sum': 'x[3] + y[4] + y[5]',
#   'B_poly_sum': 'y[3] + x[2] + x[5]'}]

# %%
# Look for the first code in the paper of IBM
criteria = {'ell': 6, 'm': 6, 'n_phys_qubits': 72, 'n_log_qubits': 12}

filtered_list = [d for d in good_configs if all(d.get(key) == value for key, value in criteria.items())]
filtered_list
# Out:
# [{'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 12,
#   'encoding_rate': 0.08333333333333333,
#   'A_poly_sum': 'x[3] + y[1] + y[2]',
#   'B_poly_sum': 'y[3] + x[1] + x[2]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 12,
#   'encoding_rate': 0.08333333333333333,
#   'A_poly_sum': 'x[3] + y[1] + y[2]',
#   'B_poly_sum': 'y[3] + x[2] + x[5]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 12,
#   'encoding_rate': 0.08333333333333333,
#   'A_poly_sum': 'x[3] + y[4] + y[5]',
#   'B_poly_sum': 'y[3] + x[1] + x[2]'},
#  {'ell': 6,
#   'm': 6,
#   'n_phys_qubits': 72,
#   'n_log_qubits': 12,
#   'encoding_rate': 0.08333333333333333,
#   'A_poly_sum': 'x[3] + y[4] + y[5]',
#   'B_poly_sum': 'y[3] + x[2] + x[5]'}]

# %%
def find_matching_config(configs, a_poly, b_poly):
    for config in configs:
        if config.get('A_polynomial') == a_poly and config.get('B_polynomial') == b_poly:
            return config  # Return the matching config if found
    return None  # Return None if no match is found

# %%
paper_config = find_matching_config(good_configs, 'x4 + y2 + y3', 'y4 + x2 + x3')

# %%
paper_config

# %%
start_time = time.time()

print('Computing code distance PARALLELIZED...')
# We compute the distance only for Z-type logical operators (the distance for X-type logical operators is the same)
# by solving an integer linear program (ILP). The ILP looks for a minimum weight Pauli Z-type operator which has an even overlap with each X-check
# and an odd overlap with logical-X operator on the i-th logical qubit. Let w_i be the optimal value of this ILP.
# Then the code distance for Z-type logical operators is dZ = min(w_1,…,w_k).
d = n
for i in range(k):
	w = distance_test_parallel(hx, lx[i,:])
	print('Logical qubit =', i+1, 'Distance =', w)
	d = min(d, w)

print(f'\nCode parameters: [n, k, d] = [{n}, {k}, {d}]')

print('Execution Time: ', round(time.time() - start_time, 1), 'seconds')

# %%
start_time = time.time()
print('Computing code distance...')
# We compute the distance only for Z-type logical operators (the distance for X-type logical operators is the same)
# by solving an integer linear program (ILP). The ILP looks for a minimum weight Pauli Z-type operator which has an even overlap with each X-check
# and an odd overlap with logical-X operator on the i-th logical qubit. Let w_i be the optimal value of this ILP.
# Then the code distance for Z-type logical operators is dZ = min(w_1,…,w_k).
d = n
for i in range(k):
	w = distance_test_parallel(hx, lx[i,:])
	print('Logical qubit =', i+1, 'Distance =', w)
	d = min(d, w)

print(f'\nCode parameters: [n, k, d] = [{n}, {k}, {d}]')
print('Execution Time: ', round(time.time() - start_time, 1), 'seconds')

# %% [markdown]
# ### Reproduction of codes in the paper

# %%
l_m = [(6, 6), (15, 3), (9, 6), (12, 6), (12, 12), (30, 6), (21, 18)]

A_B_polynomials = [
    ('x3 + y + y2', 'y3 + x + x2'),
    ('x9 + y + y2', '1 + x2 + x7'),
    ('x3 + y + y2', 'y3 + x + x2'),
    ('x3 + y + y2', 'y3 + x + x2'),
    ('x3 + y2 + y7', 'y3 + x + x2'),
    ('x9 + y + y2', 'y3 + x25 + x26'),
    ('x3 + y10 + y17', 'y5 + x3 + x19')
]

# %%
for ind, code_config in enumerate(A_B_polynomials):
    l, m  = l_m[ind]
    A_polynomial, B_polynomial = code_config

    # Create the identity matrices I_ℓ and I_m
    I_l = np.eye(l)
    I_m = np.eye(m)

    # Create the cyclic shift matrices S_ℓ and S_m
    S_l = get_cyclic_shift_matrix_S(l)
    S_m = get_cyclic_shift_matrix_S(m)

    # Create matrices x and y based on the tensor product
    x = np.kron(S_l, I_m)
    y = np.kron(I_l, S_m)

    A = get_matrix_polynomial(A_polynomial, x, y)
    B = get_matrix_polynomial(B_polynomial, x, y)

    Hx, Hz = generate_check_matrices(A, B)
    check_commute(Hx, Hz)

    # Calculate code parameters
    n = 2*l*m
    k = n - binary_matrix_rank(Hx) - binary_matrix_rank(Hz)

    print(f'Code Config l={l}, m={m}')
    print(f'[[n, k, d]]: [[{n}, {k}, d]]\n')
